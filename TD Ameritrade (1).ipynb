# %%
import requests

# %%
# the daily prices endpoint

# define our endpoint
endpoint = r"https://api.tdameritrade.com/v1/marketdata/{}/pricehistory".format('GOOG')

# define our payload
payload = {'apikey':'LMZNKLDH7INTWQAOQXKA38LKW4VKPRPD',
           'periodType':'day',
           'frequencyType':'minute',
           'frequency':'1',
           'period':'2',
           'startDate':'1554535854000',
           'extendedHours':'true'}

# time to make a request
content = requests.get(url = endpoint, params = payload)

# convert it to a dictionary
data = content.json()

# %%
# the quote endpoint

# define our endpoint
endpoint = r"https://api.tdameritrade.com/v1/marketdata/{}/quotes".format('GOOG')

# define our payload
payload = {'apikey':'LMZNKLDH7INTWQAOQXKA38LKW4VKPRPD'}

# time to make a request
content = requests.get(url = endpoint, params = payload)

# convert it to a dictionary
data = content.json()

# %%
# the quotes endpoint

# define our endpoint
endpoint = r"https://api.tdameritrade.com/v1/marketdata/quotes"

# define our payload
payload = {'apikey':'LMZNKLDH7INTWQAOQXKA38LKW4VKPRPD',
           'symbol':'GOOG,AMZN,FB,AAPL'}

# time to make a request
content = requests.get(url = endpoint, params = payload)

# convert it to a dictionary
data = content.json()
data
# Out:
# {'GOOG': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '02079K107',
#   'symbol': 'GOOG',
#   'description': 'Alphabet Inc. - Class C Capital Stock',
#   'bidPrice': 1351.3,
#   'bidSize': 500,
#   'bidId': 'K',
#   'askPrice': 1351.89,
#   'askSize': 100,
#   'askId': 'P',
#   'lastPrice': 1351.6,
#   'lastSize': 0,
#   'lastId': 'Q',
#   'openPrice': 1362.99,
#   'highPrice': 1364.53,
#   'lowPrice': 1349.3101,
#   'bidTick': ' ',
#   'closePrice': 1351.89,
#   'netChange': -0.29,
#   'totalVolume': 1038718,
#   'quoteTimeInLong': 1577493842741,
#   'tradeTimeInLong': 1577494788032,
#   'mark': 1351.89,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0243,
#   'digits': 4,
#   '52WkHigh': 1365.0,
#   '52WkLow': 997.0,
#   'nAV': 0.0,
#   'peRatio': 29.4703,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1351.89,
#   'regularMarketLastSize': 945,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1577480400585,
#   'netPercentChangeInDouble': -0.0215,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': True},
#  'AMZN': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '023135106',
#   'symbol': 'AMZN',
#   'description': 'Amazon.com, Inc. - Common Stock',
#   'bidPrice': 1869.95,
#   'bidSize': 300,
#   'bidId': 'K',
#   'askPrice': 1870.25,
#   'askSize': 900,
#   'askId': 'K',
#   'lastPrice': 1869.8,
#   'lastSize': 0,
#   'lastId': 'Q',
#   'openPrice': 1882.92,
#   'highPrice': 1901.4,
#   'lowPrice': 1866.01,
#   'bidTick': ' ',
#   'closePrice': 1869.8,
#   'netChange': 0.0,
#   'totalVolume': 6188754,
#   'quoteTimeInLong': 1577494798867,
#   'tradeTimeInLong': 1577494788670,
#   'mark': 1869.8,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0179,
#   'digits': 4,
#   '52WkHigh': 2035.8,
#   '52WkLow': 1390.3101,
#   'nAV': 0.0,
#   'peRatio': 83.8985,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 1869.8,
#   'regularMarketLastSize': 1754,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1577480400618,
#   'netPercentChangeInDouble': 0.0,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': True},
#  'FB': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '30303M102',
#   'symbol': 'FB',
#   'description': 'Facebook, Inc. - Class A Common Stock',
#   'bidPrice': 207.76,
#   'bidSize': 1100,
#   'bidId': 'K',
#   'askPrice': 207.8,
#   'askSize': 200,
#   'askId': 'Q',
#   'lastPrice': 207.76,
#   'lastSize': 0,
#   'lastId': 'Q',
#   'openPrice': 208.6697,
#   'highPrice': 208.93,
#   'lowPrice': 206.5875,
#   'bidTick': ' ',
#   'closePrice': 208.1,
#   'netChange': -0.34,
#   'totalVolume': 10287634,
#   'quoteTimeInLong': 1577494786590,
#   'tradeTimeInLong': 1577494786590,
#   'mark': 208.1,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0109,
#   'digits': 4,
#   '52WkHigh': 208.93,
#   '52WkLow': 128.56,
#   'nAV': 0.0,
#   'peRatio': 33.262,
#   'divAmount': 0.0,
#   'divYield': 0.0,
#   'divDate': '',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 208.1,
#   'regularMarketLastSize': 12324,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1577480400313,
#   'netPercentChangeInDouble': -0.1634,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': True},
#  'AAPL': {'assetType': 'EQUITY',
#   'assetMainType': 'EQUITY',
#   'cusip': '037833100',
#   'symbol': 'AAPL',
#   'description': 'Apple Inc. - Common Stock',
#   'bidPrice': 289.95,
#   'bidSize': 100,
#   'bidId': 'K',
#   'askPrice': 290.0,
#   'askSize': 1800,
#   'askId': 'Q',
#   'lastPrice': 290.0,
#   'lastSize': 200,
#   'lastId': 'Q',
#   'openPrice': 291.12,
#   'highPrice': 293.97,
#   'lowPrice': 288.12,
#   'bidTick': ' ',
#   'closePrice': 289.8,
#   'netChange': 0.2,
#   'totalVolume': 36592936,
#   'quoteTimeInLong': 1577494792223,
#   'tradeTimeInLong': 1577494792223,
#   'mark': 289.8,
#   'exchange': 'q',
#   'exchangeName': 'NASD',
#   'marginable': True,
#   'shortable': True,
#   'volatility': 0.0094,
#   'digits': 4,
#   '52WkHigh': 293.97,
#   '52WkLow': 142.0,
#   'nAV': 0.0,
#   'peRatio': 24.4504,
#   'divAmount': 3.08,
#   'divYield': 1.06,
#   'divDate': '2019-11-07 00:00:00.000',
#   'securityStatus': 'Normal',
#   'regularMarketLastPrice': 289.8,
#   'regularMarketLastSize': 22815,
#   'regularMarketNetChange': 0.0,
#   'regularMarketTradeTimeInLong': 1577480400625,
#   'netPercentChangeInDouble': 0.069,
#   'markChangeInDouble': 0.0,
#   'markPercentChangeInDouble': 0.0,
#   'regularMarketPercentChangeInDouble': 0.0,
#   'delayed': True}}
